# %%
# import libraries
import numpy as np
import pandas as pd

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Load the data
job_data = pd.read_csv("JobsFE.csv")
resume_data = pd.read_csv("Resume Data Cleaned.csv")

# %%
resume_data.head()
# Out:
#                                               skills  \
# 0  ['Big Data', 'Hadoop', 'Hive', 'Python', 'Mapr...
# 1  ['Software Development', 'Machine Learning', '...
# 2  ['Machine Learning', 'Linear Regression', 'Rid...
# 3  ['Python', 'Machine Learning', 'MySQL', 'Data ...
# 4  ['Data Analytics', 'Linear Regression', 'Logis...
#
#                                          institution degree_names  \
# 0  the amity school of engineering & technology (...       b.tech
# 1        birla institute of technology (bit), ranchi       b.tech
# 2                         djr college and university       b.tech
# 3                                  nagpur university  b.tech/b.e.
# 4                raja kashwant singh general college          b.a
#
#   graduation_year                 field_of_study  \
# 0            2019                    electronics
# 1            2018  electronics/telecommunication
# 2            2020                             it
# 3            2019  electronics/telecommunication
# 4            2020                      economics
#
#                            experience_company_names    experience_start_dates  \
# 0                                     ['coca-cola']              ['Nov 2019']
# 1                             ['axis bank limited']             ['June 2018']
# 2                                   ['remiro amio']              ['Jan 2019']
# 3         ['amz loans and mortgages erc analytics']              ['Jun 2019']
# 4  ['d&d consultancy', 'tanisha quromba brokerage']  ['Jul 2020', 'Dec 2019']
#
#         experience_end_dates  \
# 0              ['Till Date']
# 1              ['Till Date']
# 2               ['Sep 2019']
# 3              ['till date']
# 4  ['till date', 'May 2020']
#
#                            experience_related_skills  \
# 0                                     [['Big Data']]
# 1  [['Unified Payment Interface', 'Risk Predictio...
# 2                                             [None]
# 3  [['Data Analysis', 'Employee Satisfaction', 'H...
# 4                                       [None, None]
#
#                                 experience_positions  \
# 0                               ['Big Data Analyst']
# 1  ['Software Developer (Machine Learning Enginee...
# 2                                         ['Intern']
# 3                              ['Associate Analyst']
# 4  ['Associate Consultant', 'Junior Analyst Intern']
#
#                          experience_responsibilities languages  \
# 0  Technical Support\nTroubleshooting\nCollaborat...       NaN
# 1  Trade Marketing Executive\nBrand Visibility, S...       NaN
# 2  iOS Lifecycle\nRequirement Analysis\nNative Fr...       NaN
# 3  Machinery Maintenance\nTroubleshooting\nReport...       NaN
# 4  Machine Learning Leadership\nCross-Functional ...       NaN
#
#   langauge_proficiency_levels
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN

# %%
job_data.head()
# Out:
#              Job Id             workplace working_mode   salary  \
# 0  1017340707950150    panama city panama     contract  69500.0
# 1  2421048253959975         tunis tunisia    part-time  84500.0
# 2  1822636506606589       harare zimbabwe    full-time  69500.0
# 3  3068000579894602        tirana albania    temporary  75500.0
# 4  1747904829392680  city of baghdad iraq    temporary  90000.0
#
#                    position  \
# 0       procurement manager
# 1    architectural designer
# 2               art teacher
# 3  environmental consultant
# 4               art teacher
#
#                                  job_role_and_duties  \
# 0  ['promote', 'supplier', 'diversity', 'initiati...
# 1  ['prepare', 'detailed', 'architectural', 'draw...
# 2  ['coordinate', 'art', 'education', 'programs',...
# 3  ['assess', 'environmental', 'impact', 'project...
# 4  ['coordinate', 'art', 'education', 'programs',...
#
#                                      requisite_skill  \
# 0  ['supplier', 'diversity', 'programs', 'diversi...
# 1  ['architectural', 'drafting', 'autocad', '2d',...
# 2  ['art', 'education', 'curriculum', 'program', ...
# 3  ['environmental', 'impact', 'analysis', 'data'...
# 4  ['art', 'education', 'curriculum', 'program', ...
#
#                                        offer_details
# 0  ['transportation', 'benefits', 'professional',...
# 1  ['employee', 'assistance', 'programs', 'eap', ...
# 2  ['employee', 'referral', 'programs', 'financia...
# 3  ['transportation', 'benefits', 'professional',...
# 4  ['employee', 'referral', 'programs', 'financia...

# %% [markdown]
# # **TF-IDF Vectorizer , Cosine similarity and top-N**

# %%
def recommend_jobs(resume_df, jobs_df, top_n=5):
    """Recommends jobs based on a resume using TF-IDF."""

    def process_column(value):
        """Flattens nested lists and converts everything to a string."""
        if isinstance(value, list):
            # Flatten only if it's a list of lists
            flat_list = []
            for item in value:
                if isinstance(item, list):
                    flat_list.extend(item)  # Unpack sublist
                else:
                    flat_list.append(item)  # Directly add non-list items
            return ' '.join(map(str, flat_list))  # Convert to string
        return str(value)  # Convert non-lists to string

    # 1. Process resume data
    resume_text = resume_df.apply(lambda row: ' '.join([
        process_column(row['skills']),
        process_column(row['institution']),
        process_column(row['degree_names']),
        process_column(row['field_of_study']),
        process_column(row['experience_related_skills']),
        process_column(row['experience_positions']),
        process_column(row['experience_responsibilities']),
    ]), axis=1).values

    # 2. Process job postings
    jobs_text = jobs_df.apply(lambda row: ' '.join([
        process_column(row['position']),
        process_column(row['job_role_and_duties']),
        process_column(row['requisite_skill']),
        process_column(row['offer_details'])
    ]), axis=1).values

    # 3. Combine resume and job descriptions
    all_text = pd.Series(list(resume_text) + list(jobs_text))

    # 4. TF-IDF Processing
    tfidf = TfidfVectorizer(stop_words='english')
    tfidf_matrix = tfidf.fit_transform(all_text)

    resume_tfidf = tfidf_matrix[:len(resume_df)]
    jobs_tfidf = tfidf_matrix[len(resume_df):]

    # 5. Calculate Cosine Similarity
    cosine_similarities = cosine_similarity(resume_tfidf, jobs_tfidf)

    # 6. Get Recommendations
    if cosine_similarities.size > 0:
        recommended_job_indices = cosine_similarities.argsort(axis=1)[:, ::-1][0]
        num_recommendations = min(top_n, len(recommended_job_indices))
        recommended_job_indices = recommended_job_indices[:num_recommendations]

        recommended_jobs = jobs_df.iloc[recommended_job_indices.tolist()]
    else:
        recommended_jobs = pd.DataFrame()
        print("No similar jobs found.")

    return recommended_jobs

# Sample Job Data
jobs_data = {
    'Job Id': [1017340707950150],
    'workplace': ['panama city panama'],
    'working_mode': ['contract'],
    'salary': [69500.0],
    'position': ['procurement manager'],
    'job_role_and_duties': [['promote', 'supplier', 'diversity', 'initiatives']],  # List of list
    'requisite_skill': [['supplier', 'diversity', 'assessment']],  # List of list
    'offer_details': [['transportation', 'benefits']]
}
jobs_df = pd.DataFrame(jobs_data)

# Sample Resume Data
resume_data = {
    'skills': [['Big Data', 'Hadoop', 'Hive', 'Python']],  # List of list
    'institution': 'the amity school of engineering & technology (aset), noida',
    'degree_names': 'b.tech',
    'graduation_year': 2019,
    'field_of_study': 'electronics',
    'experience_related_skills': [['Big Data']],  # List of list
    'experience_positions': [['Big Data Analyst']],  # List of list
    'experience_responsibilities': [['Technical Support', 'Troubleshooting']]
}
resume_df = pd.DataFrame([resume_data])

# Call Function
recommendations = recommend_jobs(resume_df, jobs_df)
print(recommendations)
# Out:
#              Job Id           workplace working_mode   salary  \
# 0  1017340707950150  panama city panama     contract  69500.0
#
#               position                          job_role_and_duties  \
# 0  procurement manager  [promote, supplier, diversity, initiatives]
#
#                      requisite_skill               offer_details
# 0  [supplier, diversity, assessment]  [transportation, benefits]

# %% [markdown]
# # **Measure the execution time:**

# %%
import time

# Start timing
start_time = time.time()

# Call the function
recommendations = recommend_jobs(resume_df, jobs_df)

# End timing
end_time = time.time()

# Calculate and print the execution time
execution_time = end_time - start_time
print(f"Time taken to recommend jobs: {execution_time:.4f} seconds")

# Print recommendations
print(recommendations)
# Out:
# Time taken to recommend jobs: 0.0066 seconds
#              Job Id           workplace working_mode   salary  \
# 0  1017340707950150  panama city panama     contract  69500.0
#
#               position                          job_role_and_duties  \
# 0  procurement manager  [promote, supplier, diversity, initiatives]
#
#                      requisite_skill               offer_details
# 0  [supplier, diversity, assessment]  [transportation, benefits]
